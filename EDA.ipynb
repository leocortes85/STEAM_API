# %% [markdown]
# # EDA games dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %load_ext autoreload
# %autoreload 2

import utils as ut

import warnings
warnings.filterwarnings("ignore")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Reading the dataset

# %%
df_reviews = pd.read_csv('data/csv/reviews_clean.csv', encoding='utf-8')
df_games = pd.read_csv('data/csv/games_clean.csv', encoding='utf-8')
df_items = pd.read_csv('data/csv/uitems_clean.csv', encoding='utf-8')

# %%
df_games
# Out:
#        publisher      genres            item_name  price  early_access  \
# 0      Kotoshiro      Action  Lost Summoner Kitty   4.99         False
# 1      Kotoshiro      Casual  Lost Summoner Kitty   4.99         False
# 2      Kotoshiro       Indie  Lost Summoner Kitty   4.99         False
# 3      Kotoshiro  Simulation  Lost Summoner Kitty   4.99         False
# 4      Kotoshiro    Strategy  Lost Summoner Kitty   4.99         False
# ...          ...         ...                  ...    ...           ...
# 84206    No data   Adventure          Maze Run VR   4.99          True
# 84207    No data       Indie          Maze Run VR   4.99          True
# 84208    No data      Action          Maze Run VR   4.99          True
# 84209    No data  Simulation          Maze Run VR   4.99          True
# 84210    No data          VR          Maze Run VR   4.99          True
#
#        item_id  developer release_year
# 0       761140  Kotoshiro         2018
# 1       761140  Kotoshiro         2018
# 2       761140  Kotoshiro         2018
# 3       761140  Kotoshiro         2018
# 4       761140  Kotoshiro         2018
# ...        ...        ...          ...
# 84206   681550    No data      no data
# 84207   681550    No data      no data
# 84208   681550    No data      no data
# 84209   681550    No data      no data
# 84210   681550    No data      no data
#
# [84211 rows x 8 columns]

# %% [markdown]
# Initially, let's check the total number of games

# %%
total_games = len(df_games['item_name'].unique())
print(f"Total games: {total_games}")
# Out:
# Total games: 32019

# %% [markdown]
# Now, let's check the number of games per year of release

# %%
# Count the number of games released per year and organize by quantity from highest to lowest
games_per_year = df_games['release_year'].value_counts().sort_values(ascending=False)[:15]

# Print result
print(games_per_year)
# Out:
# release_year
# 2017       25766
# 2016       18010
# 2015       12596
# no data    10389
# 2014        6542
# 2013        3192
# 2012        2256
# 2011        1127
# 2010         794
# 2009         571
# 2018         503
# 2008         389
# 2007         322
# 2006         275
# 2005         175
# Name: count, dtype: int64

# %%
# Get years order
df_sorted = df_games.sort_values(by='release_year')

# Plot
plt.figure(figsize=(20, 6))
sns.countplot(data=df_sorted, x='release_year')
plt.xlabel('Year')
plt.ylabel('Qty')
plt.title('Games per Year')
plt.xticks(rotation=90)
plt.show()

# %%
# Filter the DataFrame by excluding 'no data' in the 'publisher' column
filtered_df = df_games[df_games['publisher'] != 'No data']

# Count the number of games per publisher
pub_qty = filtered_df['publisher'].value_counts()[:10]

# Filter the DataFrame by excluding 'no data' in the 'developer' column
filtered_df = df_games[df_games['developer'] != 'No data']

# Count the number of games per pev
dev_qty = filtered_df['developer'].value_counts()[:10]

#print 
print(f'Games per publisher', pub_qty)
print(f'Games per publisher', dev_qty)
# Out:
# Games per publisher publisher
# SmiteWorks USA, LLC        2364
# Ubisoft - San Francisco    2161
# KISS ltd                    804
# Ubisoft                     723
# Degica                      541
# SEGA                        466
# Paradox Interactive         448
# Big Fish Games              382
# Ronimo Games                379
# Dovetail Games - Trains     360
# Name: count, dtype: int64
# Games per publisher developer
# Ubisoft - San Francisco       2516
# SmiteWorks USA, LLC           2364
# DL Softworks                   495
# Ronimo Games                   379
# Paradox Development Studio     311
# Musopia                        285
# Arcane Raise                   268
# Dovetail Games                 256
# Choice of Games                248
# Boogygames Studios             236
# Name: count, dtype: int64

# %% [markdown]
# Plot publisher and dev records

# %%
plt.figure(figsize=(12, 5))

# Publishers plot
plt.subplot(1, 2, 1)
pub_qty.plot(kind='bar', color='blue')
plt.xlabel('Publisher') ; plt.ylabel('Games') ; plt.title('Top 10 Publishers')

# Dev plot
plt.subplot(1, 2, 2)
dev_qty.plot(kind='bar', color='tomato')
plt.xlabel('Developer') ; plt.ylabel('Games') ; plt.title('Top 10 Developers')

# show plot
plt.tight_layout()
plt.show()

# %%
# Count the number of records for each unique value in 'early_access'
early_access_counts = df_games['early_access'].value_counts()
early_access_counts
# Out:
# early_access
# False    75444
# True      8767
# Name: count, dtype: int64

# %%
# Graph the number of records for each unique value
plt.figure(figsize=(8, 6))
sns.countplot(data=df_games, x='early_access')
plt.xlabel('Early Access')
plt.ylabel('Qty')
plt.title('Number of Games by Early Access Status')
plt.show()

# %%
df_genre = df_games[df_games['genres'] != 'No data']

# %%
genre_counts = df_genre['genres'].value_counts()[:10]
print(genre_counts)
# Out:
# genres
# Indie           17124
# Action          12420
# Casual           9148
# Adventure        8846
# Simulation       7373
# Strategy         7159
# RPG              5606
# Free to Play     2211
# Early Access     1943
# VR               1712
# Name: count, dtype: int64

# %%
# Get the top 10 genres by quantity
top10_genres = df_genre['genres'].value_counts().head(10)

# Graph in a bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x=top10_genres.values, y=top10_genres.index, palette='viridis')

plt.xlabel('Qty')
plt.ylabel('Genre')
plt.title('Top 10 de Genres per Qty')
# Out:
# Text(0.5, 1.0, 'Top 10 de Genres per Qty')

# %% [markdown]
# # Model Variables
# Now, we going t select variables for our ML models.
#
# Model 1:
# The model must have an item-item relationship, that is, an item is taken, based on how similar that item is to the rest, similar ones are recommended.
# Our items are games, so we will relate them by genre and developer
#
# Model 2:
# The recommendation system must apply the user-item filter, that is, take a user, find similar users, and recommend items that those similar users liked. We will then take the relationship between users, their recommendations and the games played by users with similar characteristics.

# %%
df_games
# Out:
#        publisher      genres            item_name  price  early_access  \
# 0      Kotoshiro      Action  Lost Summoner Kitty   4.99         False
# 1      Kotoshiro      Casual  Lost Summoner Kitty   4.99         False
# 2      Kotoshiro       Indie  Lost Summoner Kitty   4.99         False
# 3      Kotoshiro  Simulation  Lost Summoner Kitty   4.99         False
# 4      Kotoshiro    Strategy  Lost Summoner Kitty   4.99         False
# ...          ...         ...                  ...    ...           ...
# 84206    No data   Adventure          Maze Run VR   4.99          True
# 84207    No data       Indie          Maze Run VR   4.99          True
# 84208    No data      Action          Maze Run VR   4.99          True
# 84209    No data  Simulation          Maze Run VR   4.99          True
# 84210    No data          VR          Maze Run VR   4.99          True
#
#        item_id  developer release_year
# 0       761140  Kotoshiro         2018
# 1       761140  Kotoshiro         2018
# 2       761140  Kotoshiro         2018
# 3       761140  Kotoshiro         2018
# 4       761140  Kotoshiro         2018
# ...        ...        ...          ...
# 84206   681550    No data      no data
# 84207   681550    No data      no data
# 84208   681550    No data      no data
# 84209   681550    No data      no data
# 84210   681550    No data      no data
#
# [84211 rows x 8 columns]

# %%
df_model1 = df_games[['item_id', 'item_name', 'genres']]

# %%
df_model1
# Out:
#        item_id            item_name      genres
# 0       761140  Lost Summoner Kitty      Action
# 1       761140  Lost Summoner Kitty      Casual
# 2       761140  Lost Summoner Kitty       Indie
# 3       761140  Lost Summoner Kitty  Simulation
# 4       761140  Lost Summoner Kitty    Strategy
# ...        ...                  ...         ...
# 84206   681550          Maze Run VR   Adventure
# 84207   681550          Maze Run VR       Indie
# 84208   681550          Maze Run VR      Action
# 84209   681550          Maze Run VR  Simulation
# 84210   681550          Maze Run VR          VR
#
# [84211 rows x 3 columns]

# %%
df_model1.drop_duplicates(inplace=True)

# %%
df_model1
# Out:
#        item_id            item_name      genres
# 0       761140  Lost Summoner Kitty      Action
# 1       761140  Lost Summoner Kitty      Casual
# 2       761140  Lost Summoner Kitty       Indie
# 3       761140  Lost Summoner Kitty  Simulation
# 4       761140  Lost Summoner Kitty    Strategy
# ...        ...                  ...         ...
# 84206   681550          Maze Run VR   Adventure
# 84207   681550          Maze Run VR       Indie
# 84208   681550          Maze Run VR      Action
# 84209   681550          Maze Run VR  Simulation
# 84210   681550          Maze Run VR          VR
#
# [84200 rows x 3 columns]

# %%
ut.data_summ(df_model1)
# Out:
# Total rows:  84200
#
# Total full null rows:  0
#       Column        Data_type  No_miss_Qty  %Missing  Missing_Qty
# 0    item_id  [<class 'int'>]        84200       0.0            0
# 1  item_name  [<class 'str'>]        84200       0.0            0
# 2     genres  [<class 'str'>]        84200       0.0            0

# %%
def summary(df_model1):
    print(f'data shape: {df_model1.shape}')
    summ = pd.DataFrame(df_model1.dtypes, columns=['data type'])
    summ['#missing'] = df_model1.isnull().sum()
    summ['%missing'] = df_model1.isnull().sum()*100/len(df_model1)
    summ['#unique'] = df_model1.nunique()
    desc = pd.DataFrame(df_model1.describe(include='all').T)
    summ['min'] = desc['min']
    summ['max'] = desc['max']
    return summ

summary(df_model1)
# Out:
# data shape: (84200, 3)
#           data type  #missing  %missing  #unique   min        max
# item_id       int64         0       0.0    32019  10.0  2028850.0
# item_name    object         0       0.0    32019   NaN        NaN
# genres       object         0       0.0      257   NaN        NaN

# %%
df_auxr = df_reviews[['user_id', 'recommend', 'sentiment_analysis']]
df_auxi = df_items[['item_id', 'item_name', 'user_id']]

# %%
df_model2 = df_auxi.merge(df_auxr, on='user_id', how='inner')
df_model2
# Out:
#          item_id                                          item_name  \
# 0             10                                     Counter-Strike
# 1             10                                     Counter-Strike
# 2             10                                     Counter-Strike
# 3             20                              Team Fortress Classic
# 4             20                              Team Fortress Classic
# ...          ...                                                ...
# 6211290   311210                        Call of Duty: Black Ops III
# 6211291   203290                    America's Army: Proving Grounds
# 6211292   290140                                       Echo of Soul
# 6211293      730                   Counter-Strike: Global Offensive
# 6211294   369200  Ghost in the Shell Stand Alone Complex First A...
#
#                    user_id  recommend  sentiment_analysis
# 0        76561197970982479       True                   2
# 1        76561197970982479       True                   2
# 2        76561197970982479       True                   2
# 3        76561197970982479       True                   2
# 4        76561197970982479       True                   2
# ...                    ...        ...                 ...
# 6211290          ApxLGhost       True                   2
# 6211291  76561198267374962       True                   2
# 6211292  76561198267374962       True                   2
# 6211293  76561198267374962       True                   2
# 6211294  76561198267374962       True                   2
#
# [6211295 rows x 5 columns]

# %%
df_model2.drop_duplicates(inplace=True)

# %%
df_model2
# Out:
#          item_id                                          item_name  \
# 0             10                                     Counter-Strike
# 3             20                              Team Fortress Classic
# 6             30                                      Day of Defeat
# 9             40                                 Deathmatch Classic
# 12            50                          Half-Life: Opposing Force
# ...          ...                                                ...
# 6211290   311210                        Call of Duty: Black Ops III
# 6211291   203290                    America's Army: Proving Grounds
# 6211292   290140                                       Echo of Soul
# 6211293      730                   Counter-Strike: Global Offensive
# 6211294   369200  Ghost in the Shell Stand Alone Complex First A...
#
#                    user_id  recommend  sentiment_analysis
# 0        76561197970982479       True                   2
# 3        76561197970982479       True                   2
# 6        76561197970982479       True                   2
# 9        76561197970982479       True                   2
# 12       76561197970982479       True                   2
# ...                    ...        ...                 ...
# 6211290          ApxLGhost       True                   2
# 6211291  76561198267374962       True                   2
# 6211292  76561198267374962       True                   2
# 6211293  76561198267374962       True                   2
# 6211294  76561198267374962       True                   2
#
# [3781488 rows x 5 columns]

# %%
row = df_model2[df_model2['item_name'] == 'Counter-Strike']
row
# Out:
#          item_id       item_name            user_id  recommend  \
# 0             10  Counter-Strike  76561197970982479       True
# 831           10  Counter-Strike            js41637       True
# 832           10  Counter-Strike            js41637       True
# 4210          10  Counter-Strike              doctr       True
# 4214          10  Counter-Strike              doctr       True
# ...          ...             ...                ...        ...
# 6209199       10  Counter-Strike            K1NGCJS       True
# 6209201       10  Counter-Strike            K1NGCJS       True
# 6210229       10  Counter-Strike       celebrexISGO       True
# 6210245       10  Counter-Strike  76561198208507532       True
# 6210246       10  Counter-Strike  76561198208507532       True
#
#          sentiment_analysis
# 0                         2
# 831                       2
# 832                       0
# 4210                      2
# 4214                      0
# ...                     ...
# 6209199                   2
# 6209201                   1
# 6210229                   2
# 6210245                   0
# 6210246                   2
#
# [5818 rows x 5 columns]

# %%
df_model2
# Out:
#          item_id                                          item_name  \
# 0             10                                     Counter-Strike
# 3             20                              Team Fortress Classic
# 6             30                                      Day of Defeat
# 9             40                                 Deathmatch Classic
# 12            50                          Half-Life: Opposing Force
# ...          ...                                                ...
# 6211290   311210                        Call of Duty: Black Ops III
# 6211291   203290                    America's Army: Proving Grounds
# 6211292   290140                                       Echo of Soul
# 6211293      730                   Counter-Strike: Global Offensive
# 6211294   369200  Ghost in the Shell Stand Alone Complex First A...
#
#                    user_id  recommend  sentiment_analysis
# 0        76561197970982479       True                   2
# 3        76561197970982479       True                   2
# 6        76561197970982479       True                   2
# 9        76561197970982479       True                   2
# 12       76561197970982479       True                   2
# ...                    ...        ...                 ...
# 6211290          ApxLGhost       True                   2
# 6211291  76561198267374962       True                   2
# 6211292  76561198267374962       True                   2
# 6211293  76561198267374962       True                   2
# 6211294  76561198267374962       True                   2
#
# [3781488 rows x 5 columns]

# %%
df_model2 = df_model2.drop_duplicates(subset=['item_id', 'user_id'], keep= 'first')

# %%
df_model2
# Out:
#          item_id                                          item_name  \
# 0             10                                     Counter-Strike
# 3             20                              Team Fortress Classic
# 6             30                                      Day of Defeat
# 9             40                                 Deathmatch Classic
# 12            50                          Half-Life: Opposing Force
# ...          ...                                                ...
# 6211290   311210                        Call of Duty: Black Ops III
# 6211291   203290                    America's Army: Proving Grounds
# 6211292   290140                                       Echo of Soul
# 6211293      730                   Counter-Strike: Global Offensive
# 6211294   369200  Ghost in the Shell Stand Alone Complex First A...
#
#                    user_id  recommend  sentiment_analysis
# 0        76561197970982479       True                   2
# 3        76561197970982479       True                   2
# 6        76561197970982479       True                   2
# 9        76561197970982479       True                   2
# 12       76561197970982479       True                   2
# ...                    ...        ...                 ...
# 6211290          ApxLGhost       True                   2
# 6211291  76561198267374962       True                   2
# 6211292  76561198267374962       True                   2
# 6211293  76561198267374962       True                   2
# 6211294  76561198267374962       True                   2
#
# [2367411 rows x 5 columns]

# %%
def rating_def(row):
    '''
    Calculates a rating based on sentiment analysis and game review recommendations made by users.

    Parameters:
    row (dict): A dictionary containing the following keys:
        - "sentiment_analysis" (int): The sentiment analysis score (0, 1 or 2).
        - "recommend" (bool): Indicates whether the reviews recommend.

    Return:
        int or None: The rating calculated as an integer between 1 and 5, or None if the inputs are invalid.
    '''
    if row["sentiment_analysis"] == 0 and not row["recommend"]:
        return 1
    elif row["sentiment_analysis"] == 0 and row["recommend"]:
        return 1
    elif row["sentiment_analysis"] == 1 and not row["recommend"]:
        return 2
    elif row["sentiment_analysis"] == 1 and row["recommend"]:
        return 3
    elif row["sentiment_analysis"] == 2 and not row["recommend"]:
        return 4
    elif row["sentiment_analysis"] == 2 and row["recommend"]:
        return 5
    else:
        return None

# %%
df_model2['rating'] = df_model2.apply(rating_def, axis=1)
df_model2.drop(columns=['recommend', 'sentiment_analysis'], inplace=True)
df_model2
# Out:
#          item_id                                          item_name  \
# 0             10                                     Counter-Strike
# 3             20                              Team Fortress Classic
# 6             30                                      Day of Defeat
# 9             40                                 Deathmatch Classic
# 12            50                          Half-Life: Opposing Force
# ...          ...                                                ...
# 6211290   311210                        Call of Duty: Black Ops III
# 6211291   203290                    America's Army: Proving Grounds
# 6211292   290140                                       Echo of Soul
# 6211293      730                   Counter-Strike: Global Offensive
# 6211294   369200  Ghost in the Shell Stand Alone Complex First A...
#
#                    user_id  rating
# 0        76561197970982479       5
# 3        76561197970982479       5
# 6        76561197970982479       5
# 9        76561197970982479       5
# 12       76561197970982479       5
# ...                    ...     ...
# 6211290          ApxLGhost       5
# 6211291  76561198267374962       5
# 6211292  76561198267374962       5
# 6211293  76561198267374962       5
# 6211294  76561198267374962       5
#
# [2367411 rows x 4 columns]

# %%
model = df_model1.merge(df_model2, on='item_name', how='inner')
model
# Out:
#          item_id_x                       item_name  genres  item_id_y  \
# 0           282010            Carmageddon Max Pack  Action     282010
# 1           282010            Carmageddon Max Pack  Action     282010
# 2           282010            Carmageddon Max Pack  Action     282010
# 3           282010            Carmageddon Max Pack  Action     282010
# 4           282010            Carmageddon Max Pack  Action     282010
# ...            ...                             ...     ...        ...
# 4340872         80  Counter-Strike: Condition Zero  Action         80
# 4340873         80  Counter-Strike: Condition Zero  Action         80
# 4340874         80  Counter-Strike: Condition Zero  Action         80
# 4340875         80  Counter-Strike: Condition Zero  Action         80
# 4340876         80  Counter-Strike: Condition Zero  Action         80
#
#                        user_id  rating
# 0                     UTNerd24       1
# 1        I_DID_911_JUST_SAYING       1
# 2                     saint556       1
# 3                       chidvd       5
# 4                       aerpub       1
# ...                        ...     ...
# 4340872                 lachwe       5
# 4340873           danebuchanan       5
# 4340874                K1NGCJS       1
# 4340875           celebrexISGO       5
# 4340876      76561198208507532       1
#
# [4340877 rows x 6 columns]

# %%
model.drop('item_id_y', axis=1, inplace=True)
model.rename(columns={'item_id_x': 'item_id'}, inplace=True)
model.drop_duplicates(inplace=True)
model
# Out:
#          item_id                       item_name  genres  \
# 0         282010            Carmageddon Max Pack  Action
# 1         282010            Carmageddon Max Pack  Action
# 2         282010            Carmageddon Max Pack  Action
# 3         282010            Carmageddon Max Pack  Action
# 4         282010            Carmageddon Max Pack  Action
# ...          ...                             ...     ...
# 4340872       80  Counter-Strike: Condition Zero  Action
# 4340873       80  Counter-Strike: Condition Zero  Action
# 4340874       80  Counter-Strike: Condition Zero  Action
# 4340875       80  Counter-Strike: Condition Zero  Action
# 4340876       80  Counter-Strike: Condition Zero  Action
#
#                        user_id  rating
# 0                     UTNerd24       1
# 1        I_DID_911_JUST_SAYING       1
# 2                     saint556       1
# 3                       chidvd       5
# 4                       aerpub       1
# ...                        ...     ...
# 4340872                 lachwe       5
# 4340873           danebuchanan       5
# 4340874                K1NGCJS       1
# 4340875           celebrexISGO       5
# 4340876      76561198208507532       1
#
# [4335484 rows x 5 columns]

# %%
row = model[model['item_name'] == 'Counter-Strike']
row
# Out:
#          item_id       item_name  genres            user_id  rating
# 4327245       10  Counter-Strike  Action  76561197970982479       5
# 4327246       10  Counter-Strike  Action            js41637       5
# 4327247       10  Counter-Strike  Action              doctr       5
# 4327248       10  Counter-Strike  Action  76561198089393905       1
# 4327249       10  Counter-Strike  Action         WeiEDKrSat       3
# ...          ...             ...     ...                ...     ...
# 4330980       10  Counter-Strike  Action             lachwe       5
# 4330981       10  Counter-Strike  Action       danebuchanan       5
# 4330982       10  Counter-Strike  Action            K1NGCJS       1
# 4330983       10  Counter-Strike  Action       celebrexISGO       5
# 4330984       10  Counter-Strike  Action  76561198208507532       1
#
# [3740 rows x 5 columns]

# %%
ut.data_summ(model)
# Out:
# Total rows:  4335484
#
# Total full null rows:  0
#       Column        Data_type  No_miss_Qty  %Missing  Missing_Qty
# 0    item_id  [<class 'int'>]      4335484       0.0            0
# 1  item_name  [<class 'str'>]      4335484       0.0            0
# 2     genres  [<class 'str'>]      4335484       0.0            0
# 3    user_id  [<class 'str'>]      4335484       0.0            0
# 4     rating  [<class 'int'>]      4335484       0.0            0

# %%
dfs = [model, df_model1, df_model2]
# Nombres correspondientes a cada DataFrame
names = ['model', 'model_games', 'model_user']

ut.save_to_csv(dfs, names)
# Out:
# DataFrame 'model' saved as 'data/csv/model.csv'
# DataFrame 'model_games' saved as 'data/csv/model_games.csv'
# DataFrame 'model_user' saved as 'data/csv/model_user.csv'
